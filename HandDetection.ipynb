# %%
import cv2
import numpy as np
cap=cv2.VideoCapture(0)

# %%
def draw_rect(frame):
    rows, cols, _ = frame.shape
    global total_rectangle, hand_rect_one_x, hand_rect_one_y, hand_rect_two_x, hand_rect_two_y
    
    total_rectangle=9

    hand_rect_one_x = np.array(
        [6 * rows / 20, 6 * rows / 20, 6 * rows / 20, 9 * rows / 20, 9 * rows / 20, 9 * rows / 20, 12 * rows / 20,
         12 * rows / 20, 12 * rows / 20], dtype=np.uint32)

    hand_rect_one_y = np.array(
        [9 * cols / 20, 10 * cols / 20, 11 * cols / 20, 9 * cols / 20, 10 * cols / 20, 11 * cols / 20, 9 * cols / 20,
         10 * cols / 20, 11 * cols / 20], dtype=np.uint32)

    hand_rect_two_x = hand_rect_one_x + 10
    hand_rect_two_y = hand_rect_one_y + 10

    for i in range(total_rectangle):
        cv2.rectangle(frame, (hand_rect_one_y[i], hand_rect_one_x[i]),
                      (hand_rect_two_y[i], hand_rect_two_x[i]),
                      (0, 255, 0), 1)

    return frame

# %%
def hand_histogram(frame):
    global hand_rect_one_x, hand_rect_two_y
    hsv_frame=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
    roi=np.zeros([90,10,3], dtype=hsv_frame.dtype)
    
    for i in range(total_rectangle):
        roi[i*10:i*10+10,0:10]=hsv_frame[hand_rect_one_x[i]:hand_rect_one_x[i] + 10,
                                          hand_rect_one_y[i]:hand_rect_one_y[i] + 10]
    hand_hist = cv2.calcHist([roi], [0, 1], None, [180, 256], [0, 180, 0, 256])
    return cv2.normalize(hand_hist, hand_hist, 0, 255, cv2.NORM_MINMAX)

# %%
def hist_masking(frame, hist):
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    dst = cv2.calcBackProject([hsv], [0, 1], hist, [0, 180, 0, 256], 1)

    disc = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (31, 31))
    cv2.filter2D(dst, -1, disc, dst)

    ret, thresh = cv2.threshold(dst, 150, 255, cv2.THRESH_BINARY)

    thresh = cv2.merge((thresh, thresh, thresh))

    return cv2.bitwise_and(frame, thresh)

# %%
traverse_point = []
def manage_img_opr(frame,hand_hist):
    masked_frame=hist_masking(frame,hand_hist)
    imgray = cv2.cvtColor(masked_frame, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(imgray, 127, 255, 0)
    im2, contour_list, hierarchy =cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
    contour_list=sorted(contour_list, key=cv2.contourArea, reverse=True)
    max_cont=contour_list[0]
    cnt_centroid = centroid(max_cont)
    cv2.circle(frame, cnt_centroid, 5, [255, 0, 255], -1)
    
    if max_cont is not None:
        hull=cv2.convexHull(max_cont,returnPoints=False)
        defects = cv2.convexityDefects(max_cont, hull)
        far_point = farthest_point(defects, max_cont, cnt_centroid)
        print("Centroid : " + str(cnt_centroid) + ", farthest Point : " + str(far_point))
        cv2.circle(frame, far_point, 5, [0, 0, 255], -1)
        if len(traverse_point) < 20:
            traverse_point.append(far_point)
        else:
            traverse_point.pop(0)
            traverse_point.append(far_point)

        draw_circles(frame, traverse_point)
        return frame

# %%
def centroid(max_contour):
    moment = cv2.moments(max_contour)
    if moment['m00'] != 0:
        cx = int(moment['m10'] / moment['m00'])
        cy = int(moment['m01'] / moment['m00'])
        return cx, cy
    else:
        return None


def farthest_point(defects, contour, centroid):
    if defects is not None and centroid is not None:
        s = defects[:, 0][:, 0]
        cx, cy = centroid

        x = np.array(contour[s][:, 0][:, 0], dtype=np.float)
        y = np.array(contour[s][:, 0][:, 1], dtype=np.float)

        xp = cv2.pow(cv2.subtract(x, cx), 2)
        yp = cv2.pow(cv2.subtract(y, cy), 2)
        dist = cv2.sqrt(cv2.add(xp, yp))

        dist_max_i = np.argmax(dist)

        if dist_max_i < len(s):
            farthest_defect = s[dist_max_i]
            farthest_point = tuple(contour[farthest_defect][0])
            return farthest_point
        else:
            return None
        
def draw_circles(frame, traverse_point):
    if traverse_point is not None:
        for i in range(len(traverse_point)):
            cv2.circle(frame, traverse_point[i], int(5 - (5 * i * 3) / 100), [0, 255, 255], -1)

# %%
flag=True
while True:
    ret,frame=cap.read()
    if flag:
        cv2.imshow('Hand Detector',draw_rect(frame))
        if 'c' == chr(cv2.waitKey(1) & 255):
            hand_hist=hand_histogram(frame)
            flag=False
            cv2.imshow('Hand Detector',frame)
    else:
        cv2.imshow('Hand Detector',manage_img_opr(frame,hand_hist))
        if cv2.waitKey(1)==13:
            break
    
#     c = cv2.waitKey(0)
    
cap.release()
cv2.destroyAllWindows()
# Out:
# Centroid : (322, 308), farthest Point : (285, 96)
# Centroid : (320, 309), farthest Point : (264, 95)
# Centroid : (322, 308), farthest Point : (262, 103)
# Centroid : (321, 308), farthest Point : (263, 98)
# Centroid : (321, 306), farthest Point : (266, 87)
# Centroid : (319, 307), farthest Point : (263, 97)
# Centroid : (321, 309), farthest Point : (265, 94)
# Centroid : (319, 308), farthest Point : (264, 99)
# Centroid : (320, 310), farthest Point : (283, 96)
# Centroid : (320, 309), farthest Point : (268, 96)
# Centroid : (318, 308), farthest Point : (260, 95)
# Centroid : (319, 309), farthest Point : (257, 98)
# Centroid : (320, 310), farthest Point : (260, 96)
# Centroid : (320, 310), farthest Point : (260, 96)
# Centroid : (319, 308), farthest Point : (258, 95)
# Centroid : (319, 308), farthest Point : (261, 96)
# Centroid : (320, 309), farthest Point : (259, 95)
# Centroid : (321, 309), farthest Point : (262, 105)
# Centroid : (321, 310), farthest Point : (264, 94)
# Centroid : (321, 307), farthest Point : (271, 92)
# Centroid : (321, 307), farthest Point : (269, 90)
# Centroid : (321, 307), farthest Point : (269, 90)
# Centroid : (321, 310), farthest Point : (283, 98)
# Centroid : (322, 308), farthest Point : (272, 90)
# Centroid : (321, 310), farthest Point : (267, 100)
# Centroid : (322, 309), farthest Point : (266, 99)
# Centroid : (321, 309), farthest Point : (265, 96)
# Centroid : (322, 308), farthest Point : (263, 94)
# Centroid : (323, 308), farthest Point : (265, 99)
# Centroid : (324, 310), farthest Point : (268, 97)
# Centroid : (326, 309), farthest Point : (278, 80)
# Centroid : (326, 308), farthest Point : (327, 100)
# Centroid : (327, 308), farthest Point : (267, 101)
# Centroid : (325, 309), farthest Point : (267, 95)
# Centroid : (324, 308), farthest Point : (284, 93)
# Centroid : (322, 308), farthest Point : (261, 96)
# Centroid : (323, 308), farthest Point : (264, 91)
# Centroid : (322, 309), farthest Point : (262, 99)
# Centroid : (322, 305), farthest Point : (268, 87)
# Centroid : (325, 308), farthest Point : (284, 97)
# Centroid : (326, 306), farthest Point : (269, 100)
# Centroid : (328, 307), farthest Point : (272, 95)
# Centroid : (329, 306), farthest Point : (272, 101)
# Centroid : (328, 305), farthest Point : (281, 87)
# Centroid : (329, 308), farthest Point : (270, 108)
# Centroid : (326, 307), farthest Point : (276, 100)
# Centroid : (322, 306), farthest Point : (272, 96)
# Centroid : (319, 307), farthest Point : (257, 95)
# Centroid : (314, 303), farthest Point : (246, 93)
# Centroid : (310, 296), farthest Point : (322, 79)
# Centroid : (307, 291), farthest Point : (372, 91)
# Centroid : (308, 296), farthest Point : (376, 95)
# Centroid : (305, 297), farthest Point : (384, 110)
# Centroid : (300, 300), farthest Point : (368, 102)
# Centroid : (301, 307), farthest Point : (365, 108)
# Centroid : (298, 312), farthest Point : (368, 117)
# Centroid : (297, 314), farthest Point : (361, 107)
# Centroid : (293, 323), farthest Point : (375, 162)
# Centroid : (294, 325), farthest Point : (380, 162)
# Centroid : (290, 334), farthest Point : (186, 479)
# Centroid : (294, 334), farthest Point : (364, 167)
# Centroid : (294, 334), farthest Point : (364, 167)
# Centroid : (301, 346), farthest Point : (366, 182)
# Centroid : (307, 349), farthest Point : (388, 197)
# Centroid : (311, 350), farthest Point : (388, 182)
# Centroid : (313, 355), farthest Point : (395, 205)
# Centroid : (313, 354), farthest Point : (422, 220)
# Centroid : (312, 355), farthest Point : (420, 216)
# Centroid : (310, 354), farthest Point : (395, 189)
# Centroid : (310, 354), farthest Point : (395, 189)
# Centroid : (308, 352), farthest Point : (389, 176)
# Centroid : (306, 355), farthest Point : (390, 176)
# Centroid : (307, 355), farthest Point : (389, 171)
# Centroid : (311, 354), farthest Point : (391, 174)
# Centroid : (313, 354), farthest Point : (403, 162)
# Centroid : (318, 354), farthest Point : (409, 165)
# Centroid : (323, 357), farthest Point : (422, 173)
# Centroid : (323, 357), farthest Point : (422, 173)
# Centroid : (326, 358), farthest Point : (429, 173)
# Centroid : (333, 357), farthest Point : (441, 177)
# Centroid : (332, 361), farthest Point : (445, 180)
# Centroid : (334, 361), farthest Point : (453, 177)
# Centroid : (340, 360), farthest Point : (459, 192)
# Centroid : (345, 358), farthest Point : (477, 206)
# Centroid : (341, 362), farthest Point : (472, 198)
# Centroid : (352, 359), farthest Point : (473, 190)
# Centroid : (352, 364), farthest Point : (479, 202)
# Centroid : (357, 363), farthest Point : (491, 202)
# Centroid : (355, 367), farthest Point : (487, 201)
# Centroid : (361, 364), farthest Point : (494, 200)
# Centroid : (359, 366), farthest Point : (504, 209)
# Centroid : (368, 364), farthest Point : (496, 200)
# Centroid : (363, 366), farthest Point : (503, 201)
# Centroid : (357, 369), farthest Point : (153, 431)
# Centroid : (366, 365), farthest Point : (488, 202)
# Centroid : (364, 365), farthest Point : (489, 219)
# Centroid : (359, 367), farthest Point : (482, 222)
# Centroid : (354, 367), farthest Point : (458, 190)
# Centroid : (351, 368), farthest Point : (466, 201)
# Centroid : (355, 365), farthest Point : (451, 199)
# Centroid : (355, 365), farthest Point : (453, 201)
# Centroid : (348, 366), farthest Point : (462, 202)
# Centroid : (350, 361), farthest Point : (447, 188)
# Centroid : (344, 365), farthest Point : (440, 195)
# Centroid : (336, 364), farthest Point : (438, 187)
# Centroid : (339, 362), farthest Point : (434, 190)
# Centroid : (334, 361), farthest Point : (430, 187)
# Centroid : (327, 361), farthest Point : (425, 189)
# Centroid : (323, 359), farthest Point : (419, 181)
# Centroid : (317, 360), farthest Point : (428, 201)
# Centroid : (313, 357), farthest Point : (412, 187)
# Centroid : (305, 356), farthest Point : (399, 180)
# Centroid : (303, 356), farthest Point : (402, 199)
# Centroid : (296, 354), farthest Point : (381, 188)
# Centroid : (291, 351), farthest Point : (370, 184)
# Centroid : (284, 353), farthest Point : (365, 190)
# Centroid : (277, 356), farthest Point : (349, 192)
# Centroid : (273, 354), farthest Point : (358, 179)
# Centroid : (273, 354), farthest Point : (358, 179)
# Centroid : (272, 353), farthest Point : (344, 189)
# Centroid : (265, 354), farthest Point : (338, 186)
# Centroid : (261, 353), farthest Point : (335, 183)
# Centroid : (252, 351), farthest Point : (321, 186)
# Centroid : (244, 351), farthest Point : (316, 193)
# Centroid : (240, 351), farthest Point : (310, 190)
# Centroid : (232, 352), farthest Point : (302, 178)
# Centroid : (232, 352), farthest Point : (302, 178)
# Centroid : (228, 353), farthest Point : (293, 188)
# Centroid : (224, 349), farthest Point : (294, 181)
# Centroid : (214, 352), farthest Point : (274, 185)
# Centroid : (215, 353), farthest Point : (278, 179)
# Centroid : (214, 355), farthest Point : (274, 184)
# Centroid : (186, 369), farthest Point : (199, 255)
# Centroid : (181, 369), farthest Point : (209, 479)
# Centroid : (175, 369), farthest Point : (210, 479)
# Centroid : (171, 369), farthest Point : (195, 478)
# Centroid : (165, 372), farthest Point : (49, 420)
# Centroid : (161, 371), farthest Point : (54, 421)
# Centroid : (169, 352), farthest Point : (232, 170)
# Centroid : (155, 369), farthest Point : (180, 479)
# Centroid : (163, 354), farthest Point : (210, 188)
# Centroid : (147, 368), farthest Point : (168, 479)
# Centroid : (143, 370), farthest Point : (181, 479)
# Centroid : (139, 369), farthest Point : (171, 479)
# Centroid : (134, 369), farthest Point : (172, 479)
# Centroid : (140, 350), farthest Point : (192, 182)
# Centroid : (125, 369), farthest Point : (169, 479)
# Centroid : (119, 370), farthest Point : (157, 478)
# Centroid : (124, 351), farthest Point : (169, 183)
# Centroid : (117, 354), farthest Point : (154, 174)
# Centroid : (111, 353), farthest Point : (147, 184)
# Centroid : (106, 353), farthest Point : (145, 188)
# Centroid : (99, 355), farthest Point : (138, 190)
# Centroid : (96, 354), farthest Point : (128, 187)
# Centroid : (91, 355), farthest Point : (132, 196)
# Centroid : (86, 359), farthest Point : (125, 195)
# Centroid : (85, 357), farthest Point : (119, 178)
# Centroid : (70, 373), farthest Point : (109, 479)
# Centroid : (79, 359), farthest Point : (116, 197)
# Centroid : (67, 373), farthest Point : (117, 479)
# Centroid : (65, 373), farthest Point : (108, 472)
# Centroid : (62, 377), farthest Point : (109, 479)
# Centroid : (70, 356), farthest Point : (106, 188)
# Centroid : (70, 359), farthest Point : (99, 186)
# Centroid : (67, 361), farthest Point : (98, 194)
# Centroid : (66, 359), farthest Point : (88, 165)
# Centroid : (66, 359), farthest Point : (88, 165)
# Centroid : (65, 357), farthest Point : (89, 161)
# Centroid : (53, 378), farthest Point : (57, 261)
# Centroid : (62, 359), farthest Point : (81, 170)
# Centroid : (62, 357), farthest Point : (74, 176)
# Centroid : (49, 381), farthest Point : (61, 254)
# Centroid : (47, 385), farthest Point : (56, 258)
# Centroid : (59, 361), farthest Point : (70, 174)
# Centroid : (59, 361), farthest Point : (70, 174)
# Centroid : (59, 358), farthest Point : (69, 177)
# Centroid : (60, 360), farthest Point : (75, 184)
# Centroid : (61, 361), farthest Point : (71, 179)
# Centroid : (51, 382), farthest Point : (54, 260)
# Centroid : (62, 360), farthest Point : (83, 192)
# Centroid : (63, 358), farthest Point : (75, 144)
# Centroid : (61, 362), farthest Point : (85, 194)
# Centroid : (50, 381), farthest Point : (52, 263)
# Centroid : (50, 383), farthest Point : (51, 263)
# Centroid : (60, 362), farthest Point : (71, 180)
# Centroid : (60, 363), farthest Point : (80, 184)
# Centroid : (60, 358), farthest Point : (74, 181)
# Centroid : (62, 359), farthest Point : (70, 158)
# Centroid : (52, 383), farthest Point : (54, 260)
# Centroid : (53, 382), farthest Point : (59, 265)
# Centroid : (64, 359), farthest Point : (85, 186)
# Centroid : (67, 362), farthest Point : (79, 176)
# Centroid : (66, 361), farthest Point : (87, 183)
# Centroid : (68, 354), farthest Point : (89, 148)
# Centroid : (69, 361), farthest Point : (83, 163)
# Centroid : (58, 381), farthest Point : (66, 265)
# Centroid : (72, 361), farthest Point : (95, 183)
# Centroid : (62, 378), farthest Point : (69, 265)
# Centroid : (75, 356), farthest Point : (97, 180)
# Centroid : (67, 378), farthest Point : (85, 266)
# Centroid : (68, 376), farthest Point : (80, 264)
# Centroid : (71, 376), farthest Point : (92, 259)
# Centroid : (85, 353), farthest Point : (110, 168)
# Centroid : (77, 376), farthest Point : (87, 253)
# Centroid : (78, 375), farthest Point : (96, 256)
# Centroid : (80, 375), farthest Point : (105, 259)
# Centroid : (96, 358), farthest Point : (136, 192)
# Centroid : (88, 373), farthest Point : (136, 479)
# Centroid : (92, 376), farthest Point : (111, 259)
# Centroid : (95, 375), farthest Point : (146, 479)
# Centroid : (107, 354), farthest Point : (149, 193)
# Centroid : (101, 375), farthest Point : (123, 261)
# Centroid : (102, 372), farthest Point : (126, 257)
# Centroid : (107, 373), farthest Point : (130, 258)
# Centroid : (109, 375), farthest Point : (147, 479)
# Centroid : (109, 375), farthest Point : (147, 479)
# Centroid : (110, 374), farthest Point : (131, 263)
# Centroid : (123, 354), farthest Point : (170, 191)
# Centroid : (115, 372), farthest Point : (135, 260)
# Centroid : (116, 373), farthest Point : (139, 262)
# Centroid : (127, 356), farthest Point : (173, 189)
# Centroid : (117, 373), farthest Point : (154, 479)
# Centroid : (120, 371), farthest Point : (152, 260)
# Centroid : (120, 371), farthest Point : (152, 260)
# Centroid : (120, 373), farthest Point : (143, 264)
# Centroid : (122, 374), farthest Point : (160, 479)
# Centroid : (122, 372), farthest Point : (148, 260)
# Centroid : (125, 374), farthest Point : (150, 259)
# Centroid : (124, 374), farthest Point : (162, 478)
# Centroid : (126, 372), farthest Point : (164, 479)
# Centroid : (140, 354), farthest Point : (193, 200)
# Centroid : (140, 354), farthest Point : (193, 200)
# Centroid : (130, 373), farthest Point : (163, 479)
# Centroid : (146, 351), farthest Point : (195, 194)
# Centroid : (133, 373), farthest Point : (173, 479)
# Centroid : (148, 353), farthest Point : (203, 204)
# Centroid : (138, 373), farthest Point : (164, 479)
# Centroid : (140, 372), farthest Point : (173, 479)
# Centroid : (143, 371), farthest Point : (173, 260)
# Centroid : (145, 372), farthest Point : (169, 262)
# Centroid : (147, 372), farthest Point : (179, 479)
# Centroid : (159, 357), farthest Point : (217, 194)
# Centroid : (150, 372), farthest Point : (181, 262)
# Centroid : (150, 374), farthest Point : (175, 267)
# Centroid : (154, 370), farthest Point : (182, 261)
# Centroid : (153, 372), farthest Point : (176, 479)
# Centroid : (155, 372), farthest Point : (186, 260)
# Centroid : (156, 372), farthest Point : (186, 479)
# Centroid : (155, 373), farthest Point : (179, 479)
# Centroid : (156, 373), farthest Point : (188, 478)
# Centroid : (157, 374), farthest Point : (194, 478)
# Centroid : (157, 375), farthest Point : (189, 265)
# Centroid : (158, 371), farthest Point : (189, 261)
# Centroid : (159, 372), farthest Point : (188, 479)
# Centroid : (161, 373), farthest Point : (187, 479)
# Centroid : (162, 372), farthest Point : (181, 262)
# Centroid : (160, 375), farthest Point : (194, 271)
# Centroid : (162, 374), farthest Point : (188, 262)
# Centroid : (162, 373), farthest Point : (190, 266)
# Centroid : (164, 372), farthest Point : (188, 266)
# Centroid : (163, 374), farthest Point : (185, 262)
# Centroid : (163, 372), farthest Point : (189, 260)
# Centroid : (161, 374), farthest Point : (194, 270)
# Centroid : (162, 373), farthest Point : (186, 259)
# Centroid : (164, 375), farthest Point : (192, 265)
# Centroid : (164, 374), farthest Point : (182, 260)
# Centroid : (179, 354), farthest Point : (240, 195)
# Centroid : (163, 373), farthest Point : (54, 422)
# Centroid : (163, 374), farthest Point : (195, 266)
# Centroid : (164, 374), farthest Point : (193, 268)
# Centroid : (164, 374), farthest Point : (189, 479)
# Centroid : (164, 374), farthest Point : (189, 479)
# Centroid : (163, 374), farthest Point : (193, 479)
# Centroid : (164, 375), farthest Point : (190, 257)
# Centroid : (161, 374), farthest Point : (50, 421)
# Centroid : (162, 374), farthest Point : (184, 267)
# Centroid : (161, 373), farthest Point : (196, 271)
# Centroid : (160, 374), farthest Point : (184, 259)
# Centroid : (160, 374), farthest Point : (179, 479)
# Centroid : (160, 374), farthest Point : (179, 479)
# Centroid : (160, 374), farthest Point : (191, 266)
# Centroid : (160, 374), farthest Point : (183, 266)
# Centroid : (159, 374), farthest Point : (181, 479)
# Centroid : (158, 375), farthest Point : (190, 265)
# Centroid : (159, 375), farthest Point : (193, 271)
# Centroid : (157, 376), farthest Point : (46, 424)
# Centroid : (158, 375), farthest Point : (195, 479)
# Centroid : (158, 374), farthest Point : (188, 479)
# Centroid : (158, 374), farthest Point : (190, 479)
# Centroid : (158, 374), farthest Point : (188, 479)
# Centroid : (157, 372), farthest Point : (186, 262)
# Centroid : (157, 374), farthest Point : (179, 267)
# Centroid : (158, 377), farthest Point : (186, 272)
# Centroid : (157, 373), farthest Point : (190, 478)
# Centroid : (157, 372), farthest Point : (178, 263)
# Centroid : (156, 374), farthest Point : (189, 270)
# Centroid : (155, 372), farthest Point : (184, 267)
# Centroid : (156, 373), farthest Point : (189, 268)
# Centroid : (157, 373), farthest Point : (183, 267)
# Centroid : (157, 373), farthest Point : (192, 267)
# Centroid : (171, 353), farthest Point : (229, 219)
# Centroid : (156, 372), farthest Point : (189, 262)
# Centroid : (156, 373), farthest Point : (169, 479)
# Centroid : (154, 373), farthest Point : (184, 261)
# Centroid : (155, 371), farthest Point : (184, 264)
# Centroid : (157, 372), farthest Point : (125, 479)
# Centroid : (156, 372), farthest Point : (119, 477)
# Centroid : (155, 375), farthest Point : (184, 260)
# Centroid : (155, 375), farthest Point : (179, 259)
# Centroid : (155, 375), farthest Point : (187, 266)
# Centroid : (154, 374), farthest Point : (183, 479)
# Centroid : (152, 375), farthest Point : (190, 271)
# Centroid : (152, 375), farthest Point : (190, 271)
# Centroid : (153, 374), farthest Point : (186, 270)
# Centroid : (152, 375), farthest Point : (183, 269)
# Centroid : (154, 374), farthest Point : (186, 478)
# Centroid : (171, 351), farthest Point : (246, 168)
# Centroid : (153, 373), farthest Point : (180, 479)
# Centroid : (172, 352), farthest Point : (255, 189)
# Centroid : (172, 352), farthest Point : (255, 189)
# Centroid : (173, 351), farthest Point : (257, 189)
# Centroid : (153, 376), farthest Point : (189, 479)
# Centroid : (174, 351), farthest Point : (260, 193)
# Centroid : (177, 348), farthest Point : (269, 175)
# Centroid : (176, 349), farthest Point : (270, 177)
# Centroid : (175, 350), farthest Point : (267, 183)
# Centroid : (175, 350), farthest Point : (266, 184)
# Centroid : (175, 350), farthest Point : (266, 184)
# Centroid : (175, 347), farthest Point : (267, 181)
# Centroid : (175, 349), farthest Point : (268, 180)
# Centroid : (156, 372), farthest Point : (167, 479)
# Centroid : (175, 349), farthest Point : (267, 181)
# Centroid : (173, 353), farthest Point : (259, 201)
# Centroid : (174, 351), farthest Point : (264, 176)
# Centroid : (157, 373), farthest Point : (182, 479)
# Centroid : (172, 355), farthest Point : (253, 186)
# Centroid : (173, 353), farthest Point : (254, 184)
# Centroid : (170, 357), farthest Point : (250, 197)
# Centroid : (170, 356), farthest Point : (243, 181)
# Centroid : (169, 358), farthest Point : (238, 181)
# Centroid : (167, 358), farthest Point : (235, 180)
# Centroid : (165, 362), farthest Point : (219, 217)
# Centroid : (167, 357), farthest Point : (225, 190)
# Centroid : (163, 364), farthest Point : (215, 228)
# Centroid : (164, 363), farthest Point : (211, 233)
# Centroid : (164, 364), farthest Point : (207, 233)
# Centroid : (165, 357), farthest Point : (219, 200)
# Centroid : (163, 362), farthest Point : (195, 231)
# Centroid : (162, 364), farthest Point : (197, 238)
# Centroid : (161, 364), farthest Point : (216, 248)
# Centroid : (162, 363), farthest Point : (193, 238)
# Centroid : (161, 364), farthest Point : (192, 238)
# Centroid : (160, 363), farthest Point : (186, 230)
# Centroid : (161, 363), farthest Point : (214, 245)
# Centroid : (163, 361), farthest Point : (188, 226)
# Centroid : (161, 361), farthest Point : (190, 227)
# Centroid : (161, 359), farthest Point : (184, 211)
# Centroid : (161, 359), farthest Point : (182, 210)
# Centroid : (161, 358), farthest Point : (192, 217)
# Centroid : (160, 359), farthest Point : (195, 211)
# Centroid : (160, 359), farthest Point : (195, 211)
# Centroid : (150, 376), farthest Point : (187, 478)
# Centroid : (162, 357), farthest Point : (206, 195)
# Centroid : (150, 374), farthest Point : (183, 479)
# Centroid : (163, 356), farthest Point : (228, 176)
# Centroid : (165, 356), farthest Point : (235, 174)
# Centroid : (165, 356), farthest Point : (234, 177)
# Centroid : (163, 359), farthest Point : (225, 212)
# Centroid : (163, 359), farthest Point : (225, 212)
# Centroid : (162, 356), farthest Point : (234, 171)
# Centroid : (163, 357), farthest Point : (225, 175)
# Centroid : (162, 359), farthest Point : (213, 208)
# Centroid : (161, 360), farthest Point : (218, 205)
# Centroid : (158, 360), farthest Point : (193, 221)
# Centroid : (158, 355), farthest Point : (180, 191)
# Centroid : (156, 360), farthest Point : (176, 218)
# Centroid : (156, 360), farthest Point : (176, 218)
# Centroid : (156, 359), farthest Point : (175, 226)
# Centroid : (157, 361), farthest Point : (177, 229)
# Centroid : (157, 361), farthest Point : (194, 233)
# Centroid : (156, 360), farthest Point : (193, 234)
# Centroid : (155, 360), farthest Point : (191, 230)
# Centroid : (156, 358), farthest Point : (175, 223)
# Centroid : (159, 356), farthest Point : (197, 197)
# Centroid : (158, 358), farthest Point : (193, 208)
# Centroid : (159, 357), farthest Point : (200, 196)
# Centroid : (160, 358), farthest Point : (207, 204)
# Centroid : (158, 361), farthest Point : (208, 207)
# Centroid : (157, 360), farthest Point : (207, 214)
# Centroid : (158, 357), farthest Point : (196, 222)
# Centroid : (156, 358), farthest Point : (183, 216)
# Centroid : (156, 359), farthest Point : (176, 219)
# Centroid : (155, 363), farthest Point : (174, 226)
# Centroid : (155, 360), farthest Point : (175, 229)
# Centroid : (155, 362), farthest Point : (174, 231)
# Centroid : (156, 363), farthest Point : (204, 238)
# Centroid : (155, 362), farthest Point : (200, 238)
# Centroid : (156, 360), farthest Point : (199, 238)
# Centroid : (155, 361), farthest Point : (192, 238)
# Centroid : (155, 360), farthest Point : (189, 236)
# Centroid : (155, 360), farthest Point : (183, 234)
# Centroid : (155, 361), farthest Point : (183, 232)
# Centroid : (155, 362), farthest Point : (179, 230)
# Centroid : (158, 359), farthest Point : (158, 231)
# Centroid : (155, 362), farthest Point : (172, 232)
# Centroid : (156, 360), farthest Point : (173, 226)
# Centroid : (155, 360), farthest Point : (176, 222)
# Centroid : (155, 359), farthest Point : (191, 222)
# Centroid : (155, 359), farthest Point : (185, 203)
# Centroid : (158, 356), farthest Point : (192, 209)
# Centroid : (157, 357), farthest Point : (196, 204)
# Centroid : (157, 356), farthest Point : (190, 194)
# Centroid : (146, 375), farthest Point : (186, 479)
# Centroid : (158, 356), farthest Point : (201, 206)
# Centroid : (159, 356), farthest Point : (196, 201)
# Centroid : (145, 377), farthest Point : (37, 421)
# Centroid : (158, 355), farthest Point : (192, 185)
# Centroid : (147, 378), farthest Point : (185, 479)
# Centroid : (155, 357), farthest Point : (188, 195)
# Centroid : (154, 360), farthest Point : (185, 213)
# Centroid : (156, 359), farthest Point : (180, 200)
# Centroid : (156, 354), farthest Point : (181, 180)
# Centroid : (155, 358), farthest Point : (186, 208)
# Centroid : (154, 358), farthest Point : (184, 203)
# Centroid : (154, 358), farthest Point : (184, 203)
# Centroid : (154, 357), farthest Point : (183, 199)
# Centroid : (151, 359), farthest Point : (181, 204)
# Centroid : (153, 354), farthest Point : (183, 197)
# Centroid : (153, 354), farthest Point : (181, 190)
# Centroid : (153, 356), farthest Point : (196, 188)
# Centroid : (152, 355), farthest Point : (199, 195)
# Centroid : (152, 359), farthest Point : (206, 199)
# Centroid : (141, 377), farthest Point : (178, 479)
# Centroid : (152, 357), farthest Point : (197, 198)
# Centroid : (150, 360), farthest Point : (178, 194)
# Centroid : (149, 365), farthest Point : (171, 227)
# Centroid : (147, 369), farthest Point : (164, 237)
# Centroid : (146, 366), farthest Point : (159, 238)
# Centroid : (145, 368), farthest Point : (159, 244)
# Centroid : (144, 369), farthest Point : (158, 244)
# Centroid : (144, 367), farthest Point : (154, 233)
# Centroid : (145, 369), farthest Point : (151, 242)
# Centroid : (145, 367), farthest Point : (153, 236)
# Centroid : (147, 365), farthest Point : (157, 239)
# Centroid : (147, 365), farthest Point : (159, 236)
# Centroid : (149, 363), farthest Point : (159, 216)
# Centroid : (148, 362), farthest Point : (159, 226)
# Centroid : (149, 362), farthest Point : (163, 218)
# Centroid : (149, 361), farthest Point : (160, 213)
# Centroid : (147, 361), farthest Point : (170, 215)
# Centroid : (147, 359), farthest Point : (175, 210)
# Centroid : (148, 361), farthest Point : (171, 194)
# Centroid : (148, 359), farthest Point : (180, 199)
# Centroid : (149, 359), farthest Point : (192, 211)
# Centroid : (150, 357), farthest Point : (189, 192)
# Centroid : (151, 357), farthest Point : (199, 206)
# Centroid : (149, 358), farthest Point : (178, 189)
# Centroid : (150, 359), farthest Point : (178, 206)
# Centroid : (147, 360), farthest Point : (174, 212)
# Centroid : (146, 361), farthest Point : (170, 215)
# Centroid : (144, 363), farthest Point : (170, 221)
# Centroid : (144, 364), farthest Point : (173, 226)
# Centroid : (142, 364), farthest Point : (172, 228)
# Centroid : (141, 363), farthest Point : (167, 230)
# Centroid : (139, 363), farthest Point : (164, 231)
# Centroid : (139, 363), farthest Point : (164, 231)
# Centroid : (139, 366), farthest Point : (168, 232)
# Centroid : (140, 363), farthest Point : (162, 232)
# Centroid : (141, 363), farthest Point : (168, 232)
# Centroid : (141, 364), farthest Point : (164, 228)
# Centroid : (141, 363), farthest Point : (181, 224)
# Centroid : (142, 363), farthest Point : (185, 224)
# Centroid : (142, 360), farthest Point : (162, 214)
# Centroid : (142, 360), farthest Point : (162, 214)
# Centroid : (144, 361), farthest Point : (186, 216)
# Centroid : (143, 363), farthest Point : (182, 213)
# Centroid : (142, 362), farthest Point : (168, 208)
# Centroid : (142, 361), farthest Point : (165, 210)
# Centroid : (142, 361), farthest Point : (164, 209)
# Centroid : (142, 362), farthest Point : (164, 212)
# Centroid : (141, 360), farthest Point : (172, 214)
# Centroid : (138, 360), farthest Point : (156, 212)
# Centroid : (135, 361), farthest Point : (168, 218)
# Centroid : (133, 361), farthest Point : (150, 216)
# Centroid : (128, 363), farthest Point : (156, 219)
# Centroid : (122, 364), farthest Point : (160, 224)
# Centroid : (116, 363), farthest Point : (150, 222)
# Centroid : (109, 363), farthest Point : (137, 222)
# Centroid : (99, 365), farthest Point : (126, 221)
# Centroid : (89, 365), farthest Point : (113, 222)
# Centroid : (81, 364), farthest Point : (106, 225)
# Centroid : (68, 369), farthest Point : (83, 224)
# Centroid : (59, 375), farthest Point : (88, 258)
# Centroid : (55, 377), farthest Point : (67, 259)
# Centroid : (45, 379), farthest Point : (62, 259)
# Centroid : (41, 379), farthest Point : (50, 262)
# Centroid : (34, 375), farthest Point : (0, 479)
# Centroid : (29, 369), farthest Point : (2, 475)
# Centroid : (28, 375), farthest Point : (30, 269)
# Centroid : (29, 374), farthest Point : (72, 479)
# Centroid : (28, 374), farthest Point : (0, 479)
# Centroid : (24, 367), farthest Point : (0, 476)
# Centroid : (26, 379), farthest Point : (0, 268)
# Centroid : (24, 374), farthest Point : (49, 479)
# Centroid : (27, 350), farthest Point : (22, 435)
# Centroid : (24, 371), farthest Point : (53, 479)
# Centroid : (26, 369), farthest Point : (19, 477)
# Centroid : (26, 372), farthest Point : (4, 270)
# Centroid : (27, 370), farthest Point : (2, 471)
# Centroid : (28, 369), farthest Point : (15, 479)
# Centroid : (29, 372), farthest Point : (44, 479)
# Centroid : (30, 375), farthest Point : (11, 268)
# Centroid : (30, 375), farthest Point : (11, 268)
# Centroid : (30, 376), farthest Point : (28, 266)
# Centroid : (33, 377), farthest Point : (31, 264)
# Centroid : (43, 375), farthest Point : (48, 264)
# Centroid : (48, 378), farthest Point : (54, 262)
# Centroid : (56, 373), farthest Point : (71, 262)
# Centroid : (63, 377), farthest Point : (79, 254)
# Centroid : (69, 370), farthest Point : (90, 227)
# Centroid : (69, 370), farthest Point : (90, 227)
# Centroid : (76, 365), farthest Point : (95, 224)
# Centroid : (85, 367), farthest Point : (108, 224)
# Centroid : (91, 366), farthest Point : (115, 223)
# Centroid : (100, 365), farthest Point : (127, 224)
# Centroid : (105, 366), farthest Point : (133, 223)
# Centroid : (112, 364), farthest Point : (147, 224)
# Centroid : (124, 362), farthest Point : (157, 222)
# Centroid : (124, 362), farthest Point : (157, 222)
# Centroid : (128, 362), farthest Point : (146, 220)
# Centroid : (133, 364), farthest Point : (167, 223)
# Centroid : (136, 365), farthest Point : (178, 223)
# Centroid : (143, 362), farthest Point : (180, 223)
# Centroid : (147, 364), farthest Point : (191, 225)
# Centroid : (152, 362), farthest Point : (173, 217)
# Centroid : (157, 361), farthest Point : (177, 211)
# Centroid : (163, 363), farthest Point : (181, 209)
# Centroid : (168, 362), farthest Point : (199, 219)
# Centroid : (173, 364), farthest Point : (201, 214)
# Centroid : (176, 365), farthest Point : (209, 218)
# Centroid : (172, 380), farthest Point : (76, 425)
# Centroid : (188, 364), farthest Point : (226, 221)
# Centroid : (191, 363), farthest Point : (251, 228)
# Centroid : (196, 360), farthest Point : (225, 180)
# Centroid : (201, 359), farthest Point : (237, 199)
# Centroid : (204, 357), farthest Point : (242, 182)
# Centroid : (207, 358), farthest Point : (245, 211)
# Centroid : (211, 357), farthest Point : (254, 192)
# Centroid : (213, 359), farthest Point : (252, 203)
# Centroid : (216, 359), farthest Point : (258, 206)
# Centroid : (217, 361), farthest Point : (255, 207)
# Centroid : (222, 358), farthest Point : (265, 196)
# Centroid : (223, 360), farthest Point : (270, 211)
# Centroid : (224, 360), farthest Point : (61, 427)
# Centroid : (229, 358), farthest Point : (280, 214)
# Centroid : (231, 359), farthest Point : (280, 215)
# Centroid : (234, 359), farthest Point : (282, 210)
# Centroid : (235, 358), farthest Point : (278, 213)
# Centroid : (234, 364), farthest Point : (282, 215)
# Centroid : (240, 357), farthest Point : (289, 211)
# Centroid : (241, 360), farthest Point : (295, 207)
# Centroid : (241, 360), farthest Point : (295, 207)
# Centroid : (226, 381), farthest Point : (127, 428)
# Centroid : (247, 354), farthest Point : (303, 208)
# Centroid : (248, 357), farthest Point : (303, 221)
# Centroid : (251, 355), farthest Point : (299, 205)
# Centroid : (249, 360), farthest Point : (304, 220)
# Centroid : (253, 356), farthest Point : (309, 219)
# Centroid : (248, 364), farthest Point : (310, 215)
# Centroid : (248, 364), farthest Point : (310, 215)
# Centroid : (255, 358), farthest Point : (107, 429)
# Centroid : (260, 354), farthest Point : (315, 213)
# Centroid : (260, 360), farthest Point : (310, 218)
# Centroid : (262, 355), farthest Point : (107, 425)
# Centroid : (261, 362), farthest Point : (113, 431)
# Centroid : (269, 363), farthest Point : (116, 427)
# Centroid : (273, 360), farthest Point : (332, 217)
# Centroid : (273, 360), farthest Point : (332, 217)
# Centroid : (270, 363), farthest Point : (100, 431)
# Centroid : (262, 381), farthest Point : (165, 431)
# Centroid : (272, 366), farthest Point : (86, 426)
# Centroid : (257, 384), farthest Point : (108, 424)
# Centroid : (278, 360), farthest Point : (138, 437)
# Centroid : (277, 362), farthest Point : (139, 431)
# Centroid : (272, 367), farthest Point : (89, 430)
# Centroid : (276, 364), farthest Point : (116, 429)
# Centroid : (281, 363), farthest Point : (347, 222)
# Centroid : (282, 363), farthest Point : (350, 220)
# Centroid : (262, 381), farthest Point : (310, 292)
# Centroid : (280, 365), farthest Point : (350, 228)
# Centroid : (267, 384), farthest Point : (189, 445)
# Centroid : (280, 365), farthest Point : (348, 228)
# Centroid : (280, 363), farthest Point : (347, 222)
# Centroid : (281, 361), farthest Point : (127, 428)
# Centroid : (280, 362), farthest Point : (351, 223)
# Centroid : (282, 362), farthest Point : (344, 230)
# Centroid : (262, 381), farthest Point : (314, 293)
# Centroid : (279, 363), farthest Point : (118, 428)
# Centroid : (262, 383), farthest Point : (102, 427)
# Centroid : (282, 363), farthest Point : (353, 229)
# Centroid : (279, 365), farthest Point : (144, 431)
# Centroid : (276, 364), farthest Point : (109, 427)
# Centroid : (255, 384), farthest Point : (110, 427)
# Centroid : (282, 364), farthest Point : (352, 230)
# Centroid : (266, 381), farthest Point : (306, 290)
# Centroid : (280, 365), farthest Point : (134, 433)
# Centroid : (280, 364), farthest Point : (100, 426)
# Centroid : (277, 367), farthest Point : (98, 425)
# Centroid : (284, 362), farthest Point : (354, 232)
# Centroid : (285, 362), farthest Point : (353, 227)
# Centroid : (285, 362), farthest Point : (353, 227)
# Centroid : (280, 362), farthest Point : (132, 432)
# Centroid : (280, 363), farthest Point : (118, 425)
# Centroid : (281, 366), farthest Point : (352, 229)
# Centroid : (262, 386), farthest Point : (161, 434)
# Centroid : (279, 365), farthest Point : (351, 226)
# Centroid : (278, 365), farthest Point : (134, 431)
# Centroid : (281, 366), farthest Point : (353, 232)
# Centroid : (281, 366), farthest Point : (353, 232)
# Centroid : (259, 383), farthest Point : (81, 425)
# Centroid : (260, 383), farthest Point : (113, 429)
# Centroid : (278, 363), farthest Point : (350, 227)
# Centroid : (281, 365), farthest Point : (351, 230)
# Centroid : (279, 367), farthest Point : (122, 433)
# Centroid : (277, 365), farthest Point : (77, 426)
# Centroid : (279, 364), farthest Point : (351, 225)
# Centroid : (279, 364), farthest Point : (351, 225)
# Centroid : (281, 365), farthest Point : (353, 229)
# Centroid : (274, 367), farthest Point : (71, 423)
# Centroid : (274, 365), farthest Point : (123, 433)
# Centroid : (282, 365), farthest Point : (349, 232)
# Centroid : (281, 366), farthest Point : (364, 249)
# Centroid : (279, 365), farthest Point : (349, 229)
# Centroid : (275, 366), farthest Point : (93, 427)
# Centroid : (279, 362), farthest Point : (351, 221)
# Centroid : (283, 361), farthest Point : (349, 218)
# Centroid : (276, 365), farthest Point : (112, 429)
# Centroid : (274, 367), farthest Point : (107, 430)
# Centroid : (282, 363), farthest Point : (138, 429)
# Centroid : (281, 364), farthest Point : (351, 222)
# Centroid : (282, 360), farthest Point : (348, 220)
# Centroid : (281, 364), farthest Point : (346, 222)
# Centroid : (279, 365), farthest Point : (349, 225)
# Centroid : (278, 363), farthest Point : (112, 427)
# Centroid : (275, 364), farthest Point : (116, 426)
# Centroid : (281, 361), farthest Point : (352, 225)
# Centroid : (265, 382), farthest Point : (302, 292)
# Centroid : (278, 363), farthest Point : (349, 224)
# Centroid : (279, 363), farthest Point : (123, 430)
# Centroid : (281, 364), farthest Point : (355, 234)
# Centroid : (279, 365), farthest Point : (133, 432)
# Centroid : (265, 381), farthest Point : (281, 479)
# Centroid : (284, 360), farthest Point : (351, 227)
# Centroid : (282, 361), farthest Point : (349, 214)
# Centroid : (278, 363), farthest Point : (353, 229)
# Centroid : (278, 363), farthest Point : (131, 441)
# Centroid : (283, 361), farthest Point : (351, 220)
# Centroid : (285, 360), farthest Point : (350, 221)
# Centroid : (285, 360), farthest Point : (350, 221)
# Centroid : (282, 362), farthest Point : (141, 432)
# Centroid : (258, 386), farthest Point : (124, 427)
# Centroid : (261, 384), farthest Point : (123, 426)
# Centroid : (279, 362), farthest Point : (102, 426)
# Centroid : (280, 361), farthest Point : (339, 227)
# Centroid : (280, 361), farthest Point : (338, 226)
# Centroid : (283, 360), farthest Point : (334, 223)
# Centroid : (283, 360), farthest Point : (334, 223)
# Centroid : (275, 364), farthest Point : (114, 434)
# Centroid : (275, 366), farthest Point : (94, 424)
# Centroid : (276, 364), farthest Point : (111, 427)
# Centroid : (262, 383), farthest Point : (322, 302)
# Centroid : (279, 363), farthest Point : (100, 426)
# Centroid : (281, 362), farthest Point : (334, 225)
# Centroid : (283, 362), farthest Point : (141, 432)
# Centroid : (283, 362), farthest Point : (141, 432)
# Centroid : (259, 383), farthest Point : (60, 424)
# Centroid : (284, 360), farthest Point : (335, 225)
# Centroid : (278, 365), farthest Point : (128, 430)
# Centroid : (278, 365), farthest Point : (110, 428)
# Centroid : (266, 379), farthest Point : (163, 431)
# Centroid : (277, 364), farthest Point : (114, 436)
# Centroid : (276, 363), farthest Point : (86, 425)
# Centroid : (279, 366), farthest Point : (133, 429)
# Centroid : (259, 385), farthest Point : (104, 427)
# Centroid : (280, 363), farthest Point : (335, 223)
# Centroid : (260, 383), farthest Point : (125, 428)
# Centroid : (280, 361), farthest Point : (340, 232)
# Centroid : (278, 361), farthest Point : (138, 433)
# Centroid : (266, 381), farthest Point : (262, 479)
# Centroid : (262, 381), farthest Point : (223, 284)
# Centroid : (281, 361), farthest Point : (127, 428)
# Centroid : (260, 386), farthest Point : (109, 431)
# Centroid : (257, 385), farthest Point : (146, 432)
# Centroid : (275, 361), farthest Point : (95, 428)
# Centroid : (258, 383), farthest Point : (106, 429)
# Centroid : (280, 361), farthest Point : (350, 217)
# Centroid : (281, 363), farthest Point : (348, 222)
# Centroid : (280, 361), farthest Point : (120, 427)
# Centroid : (279, 362), farthest Point : (117, 429)
# Centroid : (279, 362), farthest Point : (349, 226)
# Centroid : (281, 362), farthest Point : (133, 432)
# Centroid : (277, 364), farthest Point : (105, 429)
# Centroid : (280, 363), farthest Point : (136, 428)
# Centroid : (269, 369), farthest Point : (80, 426)
# Centroid : (282, 361), farthest Point : (343, 218)
# Centroid : (275, 366), farthest Point : (104, 429)
# Centroid : (280, 360), farthest Point : (340, 215)
# Centroid : (276, 365), farthest Point : (114, 428)
# Centroid : (275, 366), farthest Point : (133, 430)
# Centroid : (273, 366), farthest Point : (145, 437)
# Centroid : (276, 362), farthest Point : (335, 229)
# Centroid : (274, 364), farthest Point : (90, 426)
# Centroid : (277, 365), farthest Point : (332, 223)
# Centroid : (277, 365), farthest Point : (334, 233)
# Centroid : (279, 361), farthest Point : (331, 220)
# Centroid : (279, 361), farthest Point : (331, 220)
# Centroid : (270, 367), farthest Point : (108, 427)
# Centroid : (277, 364), farthest Point : (334, 231)
# Centroid : (273, 365), farthest Point : (111, 432)
# Centroid : (278, 362), farthest Point : (126, 431)
# Centroid : (278, 364), farthest Point : (344, 226)
# Centroid : (277, 363), farthest Point : (113, 433)
# Centroid : (277, 364), farthest Point : (98, 427)
# Centroid : (277, 364), farthest Point : (98, 427)
# Centroid : (259, 384), farthest Point : (104, 429)
# Centroid : (282, 363), farthest Point : (342, 221)
# Centroid : (284, 361), farthest Point : (340, 232)
# Centroid : (280, 363), farthest Point : (137, 431)
# Centroid : (257, 384), farthest Point : (132, 430)
# Centroid : (282, 362), farthest Point : (333, 227)
# Centroid : (258, 383), farthest Point : (157, 435)
# Centroid : (282, 363), farthest Point : (344, 229)
# Centroid : (283, 362), farthest Point : (346, 219)
# Centroid : (275, 364), farthest Point : (96, 427)
# Centroid : (276, 364), farthest Point : (85, 427)
# Centroid : (285, 360), farthest Point : (330, 225)
# Centroid : (285, 361), farthest Point : (338, 224)
# Centroid : (262, 382), farthest Point : (137, 430)
# Centroid : (256, 386), farthest Point : (117, 431)
# Centroid : (276, 364), farthest Point : (73, 423)
# Centroid : (275, 366), farthest Point : (83, 425)
# Centroid : (260, 383), farthest Point : (311, 293)
# Centroid : (283, 361), farthest Point : (325, 221)
# Centroid : (280, 359), farthest Point : (108, 427)
# Centroid : (256, 385), farthest Point : (89, 426)
# Centroid : (267, 381), farthest Point : (153, 433)
# Centroid : (279, 365), farthest Point : (94, 426)
# Centroid : (263, 384), farthest Point : (302, 291)
# Centroid : (279, 364), farthest Point : (119, 427)
# Centroid : (279, 362), farthest Point : (134, 428)
# Centroid : (280, 360), farthest Point : (343, 236)
# Centroid : (279, 364), farthest Point : (142, 431)
# Centroid : (280, 362), farthest Point : (134, 430)
# Centroid : (284, 359), farthest Point : (339, 225)
# Centroid : (285, 360), farthest Point : (340, 223)
# Centroid : (281, 363), farthest Point : (342, 229)
# Centroid : (281, 361), farthest Point : (127, 431)
# Centroid : (281, 363), farthest Point : (135, 431)
# Centroid : (261, 382), farthest Point : (138, 432)
# Centroid : (281, 362), farthest Point : (359, 247)
# Centroid : (261, 380), farthest Point : (175, 435)
# Centroid : (282, 358), farthest Point : (350, 238)
# Centroid : (281, 359), farthest Point : (348, 244)
# Centroid : (280, 361), farthest Point : (351, 245)
# Centroid : (280, 361), farthest Point : (351, 245)
# Centroid : (278, 360), farthest Point : (153, 430)
# Centroid : (261, 382), farthest Point : (313, 292)
# Centroid : (278, 363), farthest Point : (137, 429)
# Centroid : (275, 365), farthest Point : (87, 425)
# Centroid : (280, 361), farthest Point : (162, 432)
# Centroid : (272, 367), farthest Point : (83, 425)
# Centroid : (276, 363), farthest Point : (109, 434)
# Centroid : (280, 360), farthest Point : (357, 254)
# Centroid : (280, 359), farthest Point : (343, 251)
# Centroid : (279, 361), farthest Point : (145, 433)
# Centroid : (279, 361), farthest Point : (338, 248)
# Centroid : (270, 363), farthest Point : (139, 431)
# Centroid : (273, 360), farthest Point : (160, 430)
# Centroid : (271, 361), farthest Point : (134, 432)
# Centroid : (266, 364), farthest Point : (102, 429)
# Centroid : (274, 359), farthest Point : (338, 248)
# Centroid : (272, 358), farthest Point : (320, 242)
# Centroid : (266, 361), farthest Point : (85, 425)
# Centroid : (273, 358), farthest Point : (120, 430)
# Centroid : (276, 356), farthest Point : (223, 476)
# Centroid : (277, 358), farthest Point : (307, 224)
# Centroid : (259, 381), farthest Point : (256, 479)
# Centroid : (277, 358), farthest Point : (318, 218)
# Centroid : (276, 357), farthest Point : (325, 216)
# Centroid : (250, 384), farthest Point : (116, 438)
# Centroid : (275, 358), farthest Point : (340, 206)
# Centroid : (276, 358), farthest Point : (104, 428)
# Centroid : (277, 358), farthest Point : (351, 216)
# Centroid : (274, 364), farthest Point : (125, 427)
# Centroid : (258, 382), farthest Point : (141, 430)
# Centroid : (277, 363), farthest Point : (127, 431)
# Centroid : (261, 383), farthest Point : (176, 431)
# Centroid : (259, 383), farthest Point : (54, 424)
# Centroid : (274, 363), farthest Point : (113, 427)
# Centroid : (270, 368), farthest Point : (146, 436)
# Centroid : (271, 373), farthest Point : (332, 277)
# Centroid : (271, 375), farthest Point : (156, 429)
# Centroid : (271, 371), farthest Point : (174, 431)
# Centroid : (275, 368), farthest Point : (167, 429)
# Centroid : (274, 365), farthest Point : (334, 266)
# Centroid : (273, 362), farthest Point : (118, 428)
# Centroid : (273, 360), farthest Point : (151, 434)
# Centroid : (276, 362), farthest Point : (328, 240)
# Centroid : (275, 362), farthest Point : (148, 432)
# Centroid : (261, 382), farthest Point : (306, 296)
# Centroid : (258, 382), farthest Point : (132, 430)
# Centroid : (258, 382), farthest Point : (132, 430)
# Centroid : (264, 378), farthest Point : (253, 479)
# Centroid : (257, 386), farthest Point : (76, 425)
# Centroid : (263, 381), farthest Point : (158, 433)
# Centroid : (279, 360), farthest Point : (142, 429)
# Centroid : (271, 368), farthest Point : (118, 429)
# Centroid : (270, 367), farthest Point : (258, 479)
# Centroid : (267, 367), farthest Point : (263, 479)
# Centroid : (267, 367), farthest Point : (263, 479)
# Centroid : (262, 368), farthest Point : (110, 425)
# Centroid : (267, 362), farthest Point : (247, 479)
# Centroid : (264, 363), farthest Point : (115, 428)
# Centroid : (271, 357), farthest Point : (312, 229)
# Centroid : (268, 364), farthest Point : (102, 425)
# Centroid : (260, 382), farthest Point : (176, 438)
# Centroid : (260, 382), farthest Point : (176, 438)
# Centroid : (253, 383), farthest Point : (119, 427)
# Centroid : (262, 383), farthest Point : (170, 434)
# Centroid : (255, 383), farthest Point : (97, 426)
# Centroid : (274, 364), farthest Point : (100, 426)
# Centroid : (260, 383), farthest Point : (169, 431)
# Centroid : (262, 384), farthest Point : (260, 479)
# Centroid : (271, 363), farthest Point : (145, 431)
# Centroid : (265, 371), farthest Point : (104, 430)
# Centroid : (265, 370), farthest Point : (99, 426)
# Centroid : (269, 368), farthest Point : (305, 256)
# Centroid : (268, 365), farthest Point : (124, 428)
# Centroid : (268, 362), farthest Point : (128, 430)
# Centroid : (274, 359), farthest Point : (333, 238)
# Centroid : (275, 360), farthest Point : (144, 429)
# Centroid : (259, 382), farthest Point : (154, 431)
# Centroid : (276, 366), farthest Point : (325, 226)
# Centroid : (265, 383), farthest Point : (271, 479)
# Centroid : (263, 379), farthest Point : (261, 478)
# Centroid : (263, 382), farthest Point : (178, 434)
# Centroid : (277, 360), farthest Point : (149, 433)
# Centroid : (269, 365), farthest Point : (91, 429)
# Centroid : (271, 367), farthest Point : (293, 250)
# Centroid : (271, 363), farthest Point : (172, 441)
# Centroid : (273, 359), farthest Point : (301, 231)
# Centroid : (272, 359), farthest Point : (311, 226)
# Centroid : (273, 362), farthest Point : (124, 430)
# Centroid : (259, 381), farthest Point : (170, 433)
# Centroid : (261, 384), farthest Point : (159, 436)
# Centroid : (260, 385), farthest Point : (130, 427)
# Centroid : (257, 385), farthest Point : (116, 429)
# Centroid : (279, 364), farthest Point : (128, 430)
# Centroid : (262, 385), farthest Point : (144, 435)
# Centroid : (262, 385), farthest Point : (144, 435)
# Centroid : (262, 383), farthest Point : (158, 428)
# Centroid : (257, 386), farthest Point : (105, 428)
# Centroid : (284, 357), farthest Point : (351, 203)
# Centroid : (280, 360), farthest Point : (351, 215)
# Centroid : (256, 385), farthest Point : (90, 426)
# Centroid : (278, 361), farthest Point : (352, 217)
# Centroid : (281, 359), farthest Point : (354, 216)
# Centroid : (281, 359), farthest Point : (354, 216)
# Centroid : (279, 360), farthest Point : (353, 216)
# Centroid : (257, 383), farthest Point : (149, 431)
# Centroid : (265, 379), farthest Point : (258, 479)
# Centroid : (262, 381), farthest Point : (253, 479)
# Centroid : (278, 364), farthest Point : (92, 425)
# Centroid : (284, 358), farthest Point : (358, 222)
# Centroid : (259, 383), farthest Point : (125, 431)
# Centroid : (259, 383), farthest Point : (125, 431)
# Centroid : (262, 382), farthest Point : (306, 294)
# Centroid : (275, 363), farthest Point : (107, 425)
# Centroid : (259, 381), farthest Point : (250, 478)
# Centroid : (258, 381), farthest Point : (255, 479)
# Centroid : (261, 377), farthest Point : (256, 478)
# Centroid : (259, 381), farthest Point : (177, 440)
# Centroid : (277, 360), farthest Point : (339, 213)
# Centroid : (261, 384), farthest Point : (296, 295)
# Centroid : (261, 383), farthest Point : (162, 431)
# Centroid : (256, 384), farthest Point : (109, 429)
# Centroid : (257, 384), farthest Point : (98, 423)
# Centroid : (272, 363), farthest Point : (121, 433)
# Centroid : (276, 364), farthest Point : (333, 227)
# Centroid : (275, 364), farthest Point : (324, 232)
# Centroid : (270, 363), farthest Point : (105, 436)
# Centroid : (277, 364), farthest Point : (329, 232)
# Centroid : (276, 365), farthest Point : (328, 227)
# Centroid : (272, 364), farthest Point : (104, 433)
# Centroid : (277, 359), farthest Point : (333, 227)
# Centroid : (273, 365), farthest Point : (327, 233)
# Centroid : (276, 362), farthest Point : (333, 232)
# Centroid : (271, 368), farthest Point : (115, 426)
# Centroid : (275, 366), farthest Point : (327, 232)
# Centroid : (279, 363), farthest Point : (327, 225)
# Centroid : (254, 383), farthest Point : (96, 425)
# Centroid : (278, 365), farthest Point : (350, 258)
# Centroid : (276, 366), farthest Point : (326, 244)
# Centroid : (279, 362), farthest Point : (334, 223)
# Centroid : (273, 368), farthest Point : (95, 425)
# Centroid : (280, 361), farthest Point : (335, 234)
# Centroid : (276, 363), farthest Point : (324, 238)
# Centroid : (271, 367), farthest Point : (125, 434)
# Centroid : (271, 367), farthest Point : (125, 434)
# Centroid : (276, 363), farthest Point : (333, 228)
# Centroid : (273, 366), farthest Point : (331, 241)
# Centroid : (269, 368), farthest Point : (342, 245)
# Centroid : (274, 369), farthest Point : (145, 430)
# Centroid : (272, 372), farthest Point : (110, 426)
# Centroid : (260, 382), farthest Point : (143, 430)
# Centroid : (272, 371), farthest Point : (147, 429)
# Centroid : (272, 371), farthest Point : (147, 429)
# Centroid : (259, 383), farthest Point : (125, 431)
# Centroid : (274, 370), farthest Point : (367, 277)
# Centroid : (269, 371), farthest Point : (82, 424)
# Centroid : (273, 370), farthest Point : (137, 438)
# Centroid : (275, 367), farthest Point : (113, 425)
# Centroid : (275, 367), farthest Point : (364, 277)
# Centroid : (257, 383), farthest Point : (308, 289)
# Centroid : (257, 383), farthest Point : (308, 289)
# Centroid : (258, 383), farthest Point : (103, 428)
# Centroid : (272, 369), farthest Point : (350, 235)
# Centroid : (272, 371), farthest Point : (113, 430)
# Centroid : (269, 369), farthest Point : (117, 429)
# Centroid : (273, 368), farthest Point : (361, 273)
# Centroid : (274, 367), farthest Point : (343, 250)
# Centroid : (268, 369), farthest Point : (96, 424)
# Centroid : (273, 372), farthest Point : (155, 435)
# Centroid : (258, 383), farthest Point : (300, 295)
# Centroid : (264, 381), farthest Point : (171, 429)
# Centroid : (260, 381), farthest Point : (115, 430)
# Centroid : (277, 365), farthest Point : (347, 236)
# Centroid : (274, 368), farthest Point : (341, 260)
# Centroid : (272, 369), farthest Point : (128, 433)
# Centroid : (271, 371), farthest Point : (127, 432)
# Centroid : (272, 366), farthest Point : (340, 237)
# Centroid : (270, 368), farthest Point : (121, 427)
# Centroid : (259, 379), farthest Point : (253, 479)
# Centroid : (273, 365), farthest Point : (335, 252)
# Centroid : (272, 365), farthest Point : (115, 427)
# Centroid : (274, 369), farthest Point : (118, 428)
# ...
# Centroid : (234, 423), farthest Point : (98, 429)
# Centroid : (250, 422), farthest Point : (106, 429)
# Centroid : (248, 425), farthest Point : (157, 433)
# Centroid : (223, 426), farthest Point : (55, 424)
# Centroid : (246, 424), farthest Point : (154, 437)
# Centroid : (244, 424), farthest Point : (121, 429)
# Centroid : (241, 424), farthest Point : (111, 437)
# Centroid : (245, 421), farthest Point : (250, 366)
# Centroid : (252, 425), farthest Point : (308, 446)
# Centroid : (237, 425), farthest Point : (122, 432)
# Centroid : (255, 424), farthest Point : (185, 433)
# Centroid : (251, 423), farthest Point : (183, 442)
# Centroid : (256, 417), farthest Point : (199, 437)
# Centroid : (247, 423), farthest Point : (146, 432)
# Centroid : (244, 422), farthest Point : (177, 437)
# Centroid : (234, 424), farthest Point : (98, 430)
# Centroid : (258, 421), farthest Point : (187, 435)
# Centroid : (253, 426), farthest Point : (180, 433)
# Centroid : (254, 422), farthest Point : (188, 435)
# Centroid : (250, 421), farthest Point : (168, 432)
# Centroid : (229, 422), farthest Point : (66, 424)
# Centroid : (252, 422), farthest Point : (167, 441)
# Centroid : (249, 421), farthest Point : (125, 435)
# Centroid : (243, 420), farthest Point : (138, 434)
# Centroid : (247, 422), farthest Point : (143, 431)
# Centroid : (231, 422), farthest Point : (73, 426)
# Centroid : (258, 421), farthest Point : (253, 364)
# Centroid : (252, 421), farthest Point : (168, 434)
# Centroid : (238, 421), farthest Point : (54, 426)
# Centroid : (245, 427), farthest Point : (128, 429)
# Centroid : (253, 418), farthest Point : (258, 359)
# Centroid : (247, 421), farthest Point : (251, 365)
# Centroid : (245, 429), farthest Point : (112, 429)
# Centroid : (229, 424), farthest Point : (71, 426)
# Centroid : (246, 421), farthest Point : (172, 433)
# Centroid : (246, 421), farthest Point : (172, 433)
# Centroid : (243, 421), farthest Point : (167, 433)
# Centroid : (236, 427), farthest Point : (115, 432)
# Centroid : (241, 422), farthest Point : (105, 433)
# Centroid : (251, 424), farthest Point : (310, 420)
# Centroid : (240, 423), farthest Point : (85, 429)
# Centroid : (253, 421), farthest Point : (315, 435)
# Centroid : (247, 420), farthest Point : (135, 435)
# Centroid : (247, 420), farthest Point : (135, 435)
# Centroid : (243, 423), farthest Point : (137, 432)
# Centroid : (231, 424), farthest Point : (95, 433)
# Centroid : (220, 424), farthest Point : (79, 427)
# Centroid : (247, 425), farthest Point : (146, 435)
# Centroid : (229, 425), farthest Point : (71, 426)
# Centroid : (229, 423), farthest Point : (77, 435)
# Centroid : (226, 425), farthest Point : (48, 424)
# Centroid : (226, 425), farthest Point : (48, 424)
# Centroid : (246, 422), farthest Point : (132, 432)
# Centroid : (252, 427), farthest Point : (313, 449)
# Centroid : (253, 423), farthest Point : (171, 438)
# Centroid : (249, 422), farthest Point : (137, 435)
# Centroid : (226, 425), farthest Point : (58, 426)
# Centroid : (252, 424), farthest Point : (166, 432)
# Centroid : (230, 431), farthest Point : (60, 425)
# Centroid : (240, 423), farthest Point : (89, 426)
# Centroid : (244, 426), farthest Point : (136, 432)
# Centroid : (240, 424), farthest Point : (94, 428)
# Centroid : (234, 426), farthest Point : (102, 433)
# Centroid : (241, 426), farthest Point : (94, 425)
# Centroid : (251, 421), farthest Point : (190, 433)
# Centroid : (240, 421), farthest Point : (104, 432)
# Centroid : (240, 425), farthest Point : (104, 434)
# Centroid : (259, 421), farthest Point : (183, 433)
# Centroid : (251, 420), farthest Point : (188, 444)
# Centroid : (250, 424), farthest Point : (153, 434)
# Centroid : (245, 422), farthest Point : (168, 431)
# Centroid : (255, 421), farthest Point : (176, 436)
# Centroid : (241, 425), farthest Point : (106, 434)
# Centroid : (232, 422), farthest Point : (121, 432)
# Centroid : (251, 421), farthest Point : (303, 449)
# Centroid : (234, 425), farthest Point : (118, 432)
# Centroid : (255, 425), farthest Point : (323, 450)
# Centroid : (245, 422), farthest Point : (104, 429)
# Centroid : (252, 421), farthest Point : (198, 434)
# Centroid : (239, 422), farthest Point : (129, 436)
# Centroid : (257, 420), farthest Point : (197, 436)
# Centroid : (240, 428), farthest Point : (111, 434)
# Centroid : (243, 419), farthest Point : (143, 433)
# Centroid : (244, 421), farthest Point : (144, 431)
# Centroid : (245, 427), farthest Point : (134, 431)
# Centroid : (258, 418), farthest Point : (192, 434)
# Centroid : (242, 425), farthest Point : (112, 435)
# Centroid : (259, 420), farthest Point : (184, 432)
# Centroid : (258, 424), farthest Point : (157, 432)
# Centroid : (248, 423), farthest Point : (182, 435)
# Centroid : (254, 420), farthest Point : (193, 435)
# Centroid : (236, 427), farthest Point : (96, 429)
# Centroid : (236, 427), farthest Point : (96, 429)
# Centroid : (253, 426), farthest Point : (169, 437)
# Centroid : (243, 425), farthest Point : (162, 443)
# Centroid : (255, 420), farthest Point : (151, 436)
# Centroid : (252, 428), farthest Point : (166, 438)
# Centroid : (242, 426), farthest Point : (101, 432)
# Centroid : (249, 418), farthest Point : (129, 429)
# Centroid : (283, 413), farthest Point : (382, 369)
# Centroid : (283, 413), farthest Point : (382, 369)
# Centroid : (284, 384), farthest Point : (218, 406)
# Centroid : (216, 443), farthest Point : (157, 424)
# Centroid : (37, 9), farthest Point : (0, 4)
# Centroid : (26, 12), farthest Point : (49, 3)
# Centroid : (24, 14), farthest Point : (51, 1)
# Centroid : (32, 19), farthest Point : (66, 27)
# Centroid : (26, 8), farthest Point : (47, 8)
# Centroid : (24, 13), farthest Point : (48, 1)
# Centroid : (34, 16), farthest Point : (74, 12)
# Centroid : (24, 11), farthest Point : (51, 3)
# Centroid : (31, 16), farthest Point : (63, 16)
# Centroid : (36, 17), farthest Point : (78, 20)
# Centroid : (31, 17), farthest Point : (62, 34)
# Centroid : (30, 14), farthest Point : (55, 0)
# Centroid : (28, 14), farthest Point : (55, 21)
# Centroid : (30, 15), farthest Point : (63, 16)
# Centroid : (32, 17), farthest Point : (65, 17)
# Centroid : (49, 22), farthest Point : (120, 29)
# Centroid : (30, 14), farthest Point : (58, 0)
# Centroid : (58, 450), farthest Point : (83, 437)
# Centroid : (25, 13), farthest Point : (55, 0)
# Centroid : (187, 369), farthest Point : (174, 346)
# Centroid : (186, 333), farthest Point : (207, 270)
# Centroid : (186, 363), farthest Point : (148, 380)
# Centroid : (182, 336), farthest Point : (218, 268)
# Centroid : (183, 350), farthest Point : (236, 339)
# Centroid : (178, 350), farthest Point : (229, 328)
# Centroid : (176, 357), farthest Point : (140, 435)
# Centroid : (175, 356), farthest Point : (141, 437)
# Centroid : (170, 364), farthest Point : (130, 444)
# Centroid : (166, 368), farthest Point : (123, 442)
# Centroid : (164, 365), farthest Point : (129, 443)
# Centroid : (156, 380), farthest Point : (101, 440)
# Centroid : (154, 377), farthest Point : (123, 450)
# Centroid : (147, 387), farthest Point : (77, 429)
# Centroid : (143, 392), farthest Point : (121, 466)
# Centroid : (136, 398), farthest Point : (121, 479)
# Centroid : (128, 399), farthest Point : (100, 463)
# Centroid : (114, 406), farthest Point : (132, 342)
# Centroid : (114, 406), farthest Point : (132, 342)
# Centroid : (74, 440), farthest Point : (16, 414)
# Centroid : (72, 452), farthest Point : (50, 426)
# Centroid : (41, 11), farthest Point : (70, 2)
# Centroid : (109, 18), farthest Point : (131, 19)
# Centroid : (44, 11), farthest Point : (11, 1)
# Centroid : (46, 10), farthest Point : (22, 5)
# Centroid : (365, 107), farthest Point : (378, 119)
# Centroid : (365, 107), farthest Point : (378, 119)
# Centroid : (57, 8), farthest Point : (96, 0)
# Centroid : (365, 104), farthest Point : (385, 108)
# Centroid : (61, 9), farthest Point : (99, 0)
# Centroid : (367, 103), farthest Point : (384, 111)
# Centroid : (369, 98), farthest Point : (387, 97)
# Centroid : (370, 99), farthest Point : (382, 96)
# Centroid : (419, 137), farthest Point : (436, 146)
# Centroid : (367, 101), farthest Point : (383, 114)
# Centroid : (364, 102), farthest Point : (383, 112)
# Centroid : (59, 5), farthest Point : (94, 4)
# Centroid : (262, 151), farthest Point : (285, 175)
# Centroid : (366, 104), farthest Point : (384, 114)
# Centroid : (366, 104), farthest Point : (384, 114)
# Centroid : (419, 140), farthest Point : (389, 126)
# Centroid : (99, 6), farthest Point : (128, 0)
# Centroid : (370, 102), farthest Point : (385, 113)
# Centroid : (368, 101), farthest Point : (382, 112)
# Centroid : (368, 102), farthest Point : (382, 113)
# Centroid : (367, 107), farthest Point : (382, 116)
# Centroid : (64, 9), farthest Point : (44, 0)
# Centroid : (610, 219), farthest Point : (619, 267)
# Centroid : (366, 105), farthest Point : (386, 104)
# Centroid : (364, 103), farthest Point : (382, 114)
# Centroid : (259, 145), farthest Point : (269, 172)
# Centroid : (366, 102), farthest Point : (381, 114)
# Centroid : (365, 100), farthest Point : (363, 122)
# Centroid : (258, 146), farthest Point : (250, 107)
# Centroid : (362, 97), farthest Point : (377, 98)
# Centroid : (260, 144), farthest Point : (281, 178)
# Centroid : (415, 135), farthest Point : (381, 140)
# Centroid : (363, 98), farthest Point : (381, 107)
# Centroid : (614, 293), farthest Point : (623, 328)
# Centroid : (363, 97), farthest Point : (381, 104)
# Centroid : (363, 97), farthest Point : (353, 116)
# Centroid : (263, 149), farthest Point : (283, 178)
# Centroid : (429, 135), farthest Point : (397, 128)
# Centroid : (363, 97), farthest Point : (381, 104)
# Centroid : (362, 99), farthest Point : (384, 103)
# Centroid : (420, 124), farthest Point : (436, 146)
# Centroid : (365, 98), farthest Point : (381, 110)
# Centroid : (59, 6), farthest Point : (80, 5)
# Centroid : (375, 106), farthest Point : (400, 138)
# Centroid : (366, 99), farthest Point : (380, 110)
# Centroid : (359, 99), farthest Point : (363, 111)
# Centroid : (263, 156), farthest Point : (241, 164)
# Centroid : (366, 100), farthest Point : (382, 107)
# Centroid : (32, 7), farthest Point : (15, 3)
# Centroid : (361, 100), farthest Point : (377, 112)
# Centroid : (360, 108), farthest Point : (376, 120)
# Centroid : (51, 14), farthest Point : (12, 1)
# Centroid : (96, 458), farthest Point : (55, 477)
# Centroid : (115, 450), farthest Point : (66, 479)
# Centroid : (161, 396), farthest Point : (93, 479)
# Centroid : (181, 379), farthest Point : (121, 466)
# Centroid : (211, 327), farthest Point : (169, 371)
# Centroid : (223, 321), farthest Point : (195, 361)
# Centroid : (242, 325), farthest Point : (291, 367)
# Centroid : (233, 310), farthest Point : (276, 294)
# Centroid : (238, 308), farthest Point : (282, 290)
# Centroid : (242, 302), farthest Point : (286, 283)
# Centroid : (236, 379), farthest Point : (304, 325)
# Centroid : (216, 404), farthest Point : (222, 449)
# Centroid : (235, 386), farthest Point : (293, 325)
# Centroid : (225, 407), farthest Point : (230, 447)
# Centroid : (67, 24), farthest Point : (134, 20)
# Centroid : (233, 407), farthest Point : (245, 445)
# Centroid : (237, 404), farthest Point : (245, 443)
# Centroid : (243, 404), farthest Point : (250, 445)
# Centroid : (274, 327), farthest Point : (323, 343)
# Centroid : (251, 409), farthest Point : (268, 446)
# Centroid : (41, 20), farthest Point : (74, 10)
# Centroid : (266, 404), farthest Point : (227, 414)
# Centroid : (273, 406), farthest Point : (234, 411)
# Centroid : (42, 23), farthest Point : (74, 26)
# Centroid : (45, 20), farthest Point : (72, 26)
# Centroid : (42, 21), farthest Point : (70, 27)
# Centroid : (48, 20), farthest Point : (87, 7)
# Centroid : (53, 24), farthest Point : (89, 37)
# Centroid : (334, 332), farthest Point : (305, 310)
# Centroid : (52, 24), farthest Point : (82, 41)
# Centroid : (81, 20), farthest Point : (144, 24)
# Centroid : (302, 385), farthest Point : (269, 395)
# Centroid : (302, 385), farthest Point : (269, 395)
# Centroid : (299, 387), farthest Point : (330, 406)
# Centroid : (46, 26), farthest Point : (68, 7)
# Centroid : (47, 24), farthest Point : (78, 19)
# Centroid : (303, 383), farthest Point : (327, 352)
# Centroid : (300, 379), farthest Point : (339, 387)
# Centroid : (296, 380), farthest Point : (332, 389)
# Centroid : (297, 386), farthest Point : (310, 422)
# Centroid : (48, 20), farthest Point : (71, 0)
# Centroid : (295, 385), farthest Point : (319, 418)
# Centroid : (292, 385), farthest Point : (316, 351)
# Centroid : (322, 311), farthest Point : (303, 267)
# Centroid : (287, 378), farthest Point : (255, 395)
# Centroid : (291, 389), farthest Point : (312, 422)
# Centroid : (282, 388), farthest Point : (300, 420)
# Centroid : (290, 388), farthest Point : (309, 422)
# Centroid : (283, 390), farthest Point : (302, 421)
# Centroid : (283, 392), farthest Point : (308, 422)
# Centroid : (284, 391), farthest Point : (305, 422)
# Centroid : (286, 389), farthest Point : (298, 423)
# Centroid : (283, 391), farthest Point : (303, 421)
# Centroid : (285, 392), farthest Point : (303, 424)
# Centroid : (286, 391), farthest Point : (305, 425)
# Centroid : (285, 391), farthest Point : (306, 422)
# Centroid : (284, 391), farthest Point : (304, 423)
# Centroid : (283, 391), farthest Point : (303, 426)
# Centroid : (280, 391), farthest Point : (291, 423)
# Centroid : (280, 391), farthest Point : (292, 425)
# Centroid : (280, 392), farthest Point : (300, 360)
# Centroid : (281, 394), farthest Point : (295, 430)
# Centroid : (280, 395), farthest Point : (301, 423)
# Centroid : (279, 395), farthest Point : (291, 427)
# Centroid : (281, 396), farthest Point : (296, 432)
# Centroid : (281, 396), farthest Point : (296, 432)
# Centroid : (281, 397), farthest Point : (302, 431)
# Centroid : (282, 396), farthest Point : (292, 432)
# Centroid : (280, 395), farthest Point : (288, 430)
# Centroid : (280, 396), farthest Point : (298, 428)
# Centroid : (280, 398), farthest Point : (279, 436)
# Centroid : (281, 398), farthest Point : (287, 435)
# Centroid : (282, 398), farthest Point : (297, 433)
# Centroid : (280, 398), farthest Point : (295, 435)
# Centroid : (280, 400), farthest Point : (293, 436)
# Centroid : (53, 22), farthest Point : (84, 36)
# Centroid : (284, 401), farthest Point : (294, 438)
# Centroid : (299, 356), farthest Point : (289, 437)
# Centroid : (287, 402), farthest Point : (298, 441)
# Centroid : (287, 402), farthest Point : (252, 386)
# Centroid : (288, 402), farthest Point : (284, 442)
# Centroid : (291, 402), farthest Point : (259, 383)
# Centroid : (43, 15), farthest Point : (17, 0)
# Centroid : (48, 16), farthest Point : (75, 35)
# Centroid : (316, 324), farthest Point : (288, 286)
# Centroid : (288, 396), farthest Point : (292, 434)
# Centroid : (288, 399), farthest Point : (297, 437)
# Centroid : (292, 400), farthest Point : (294, 437)
# Centroid : (289, 402), farthest Point : (300, 440)
# Centroid : (308, 323), farthest Point : (291, 282)
# Centroid : (312, 327), farthest Point : (289, 283)
# Centroid : (289, 402), farthest Point : (298, 440)
# Centroid : (40, 15), farthest Point : (66, 15)
# Centroid : (286, 390), farthest Point : (316, 397)
# Centroid : (288, 398), farthest Point : (292, 436)
# Centroid : (286, 402), farthest Point : (253, 383)
# Centroid : (286, 401), farthest Point : (292, 440)
# Centroid : (306, 319), farthest Point : (348, 336)
# Centroid : (286, 403), farthest Point : (286, 440)
# Centroid : (286, 400), farthest Point : (293, 439)
# Centroid : (290, 405), farthest Point : (250, 392)
# Centroid : (311, 334), farthest Point : (282, 308)
# Centroid : (294, 404), farthest Point : (299, 443)
# Centroid : (44, 16), farthest Point : (80, 0)
# Centroid : (334, 339), farthest Point : (297, 336)
# Centroid : (315, 404), farthest Point : (322, 430)
# Centroid : (46, 19), farthest Point : (77, 13)
# Centroid : (45, 18), farthest Point : (68, 0)
# Centroid : (42, 22), farthest Point : (68, 14)
# Centroid : (46, 19), farthest Point : (69, 0)
# Centroid : (46, 24), farthest Point : (67, 12)
# Centroid : (44, 21), farthest Point : (67, 34)
# Centroid : (42, 24), farthest Point : (66, 26)
# Centroid : (345, 353), farthest Point : (323, 343)
# Centroid : (40, 24), farthest Point : (61, 12)
# Centroid : (51, 26), farthest Point : (77, 48)
# Centroid : (45, 24), farthest Point : (70, 28)
# Centroid : (335, 352), farthest Point : (308, 342)
# Centroid : (328, 351), farthest Point : (305, 338)
# Centroid : (300, 421), farthest Point : (300, 456)
